# %% [markdown]
# ## Training YOLO26m detector on UA-DETRAC dataset

# %%
from ultralytics import YOLO
import wandb

# %%
wandb.login()
model_name = 'yolo26m.pt'
model = YOLO(model_name)
model.train(
    cfg = '../experiments/bytetrack/exp001_10SR/train/train.yaml'
)
