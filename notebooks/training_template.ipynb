# %% [markdown]
# ## Training YOLO26m detector on UA-DETRAC dataset

# %%
from ultralytics import YOLO
import wandb

# %% [markdown]
# Repeat for each config in configs/yolo_detector:

# %%
wandb.login()
model_name = 'yolo26m.pt'
model = YOLO(model_name)
model.train(
    cfg = '../experiments/configs/yolo_detector/exp001_10SR/train.yaml' 
)

# %% [markdown]
# Model selection is performed directly on wandb: the "overview" section provides metrics computed with imgsz=960 on validation set. These metrics are used to perform selection of models
